# %%
import matplotlib.pyplot as plt
# matplotlib 패키지(디렉토리)의 pyplot 모듈(파일)을 plt라는 별명으로 import
# pyplot 모듈: 시각화를 위한 함수들이 포함

import seaborn as sns  # 예제 데이터 셋

# %%
# seaborn 패키지의 tips 예제 데이터 셋을 로드.
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # matplotlib.pyplot 모듈을 사용한 시각화(Visualization)

# %%
# 1. figure 객체 생성
fig = plt.figure()

# 2. figure 객체에 subplot을 생성해서 추가
axis = fig.add_subplot(1, 1, 1)
# nows = 1(subplot의 row의 개수), ncols=1(subplot의 column 개수), index=1(subplot의 번호)

# 3. subplot에 그래프를 그림
axis.hist(x=tips['total_bill'])

# 4. 그래프 옵션 설정
axis.set_title('Histogram of Total Bill')
axis.set_xlabel('Total Bill')
axis.set_ylabel('Counts')

# 5. 그래프 보여주기
plt.show()

# %%
# 1개의 figure에 histogram과 scatter plot을 그리기
# 1. Figure 생성
fig = plt.figure()

# 2. subplot을 추가
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

# 3. subplot에 그래프 그리기
ax1.hist(x=tips['total_bill'])
ax2.scatter(x=tips['total_bill'], y=tips['tip'])

# 4. 그래프 옵션 
ax1.set_title('Histogram of Total Bill')
ax2.set_title('Total Bill vs Tip')

# 5. 그래프 보여주기
plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_subplot(211)  # add_subplot(2, 1, 1)
ax2 = fig.add_subplot(212)  # add_subplot(2, 1, 2)

ax1.hist(x=tips['total_bill'])
ax2.scatter(x=tips['total_bill'], y=tips['tip'])

plt.show()

# %%
# Figure 생성 + subplot 생성/추가
fig, axes = plt.subplots(nrows=2, ncols=1)
#> matplotlib.pyplot.subplots() 함수의 리턴:
#>  (1) Figure 객체 
#>  (2) Subplot들의 배열(array)

axes[0].hist(x=tips['total_bill'])
axes[1].hist(x=tips['tip'])

# 옵션 설정

plt.show()

# %%
# 1개의 Figure에 Subplot이 1개만 있는 경우에는,
# matplotlib.pyplot 모듈의 top-lvel 함수(plot, hist, scatter, boxplot, ...)들만 사용해도 됨
plt.hist(x=tips['total_bill'])
plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Counts')
plt.show()

# %% [markdown]
# # matplotlib.pyplot의 top-level 그래프 함수

# %% [markdown]
# ## 선 그래프(plot)

# %%
import numpy as np #np.random 모듈을 사용하기 위해서

# %%
np.random.seed(1)
data = np.random.rand(10)
print(data)
# Out:
# [4.17022005e-01 7.20324493e-01 1.14374817e-04 3.02332573e-01
#  1.46755891e-01 9.23385948e-02 1.86260211e-01 3.45560727e-01
#  3.96767474e-01 5.38816734e-01]

# %%
plt.plot(data)
plt.grid()
plt.show()

# %%
plt.plot(data, 'bo-')
#> fmt: 'bo-'
#> color=b(blue), marker='0', linestyle='-' (solid line)
plt.show()

# %%
plt.plot(data, 'rs--')  # color=red, marker=square, linestyle=dashed line
plt.show()

# %%
plt.plot(data, color='green', marker='^', linestyle=':', mfc='k', mec='red')
plt.show()

# %%
# 1개의 plot에 여러개의 선 그래프 그리기
np.random.seed(1)
y1 = np.random.rand(10)
y2 = np.random.rand(10)
y3 = np.random.rand(10)

plt.plot(y1, 'r-', label='Data I')  # red solid line
plt.plot(y2, 'g:', label='Data II')  # green dotted line
plt.plot(y3, 'b--', label='data III') # blue dashed line

plt.legend(loc='upper right')  # 각각의 plot에 설정된 label들을 범례로 보여주기 

plt.show()

# %% [markdown]
# ## 상자 그림(Box Plot

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
plt.boxplot(x=tips['total_bill'], labels=['total bill'])
plt.show()

# %%
plt.boxplot(x=[tips.total_bill, tips.tip],
            labels=['Total Bill', 'Tip'])
plt.show()

# %%
# 성별 tip의 기술 통계량 요약 -> boxplot
male_tip = tips[tips['sex'] == 'Male']['tip']
female_tip = tips[tips['sex'] == 'Female']['tip']

print(male_tip.describe())
print()
print(female_tip.describe())
# Out:
# count    157.000000
# mean       3.089618
# std        1.489102
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.760000
# max       10.000000
# Name: tip, dtype: float64
#
# count    87.000000
# mean      2.833448
# std       1.159495
# min       1.000000
# 25%       2.000000
# 50%       2.750000
# 75%       3.500000
# max       6.500000
# Name: tip, dtype: float64

# %%
plt.boxplot(x=np.array([male_tip, female_tip], dtype='object'), labels=['Male', 'Female'])
plt.show()

# %%
# 시간별 tip의 기술 통계량 요약 -> boxplot 
dinner_tip = tips[tips['time'] == 'Dinner']['tip']
dinner_tip.describe()
# Out:
# count    176.000000
# mean       3.102670
# std        1.436243
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.687500
# max       10.000000
# Name: tip, dtype: float64

# %%
lunch_tip = tips[tips.time == 'Lunch'].tip
lunch_tip.describe()
# Out:
# count    68.000000
# mean      2.728088
# std       1.205345
# min       1.250000
# 25%       2.000000
# 50%       2.250000
# 75%       3.287500
# max       6.700000
# Name: tip, dtype: float64

# %%
plt.boxplot(x=np.array([lunch_tip, dinner_tip], dtype='object'), 
        labels=['lunch', 'dinner'])
plt.show()

# %%
# 요일별 tip의 기술 통계량 -> boxplot
# tips.day.unique()
tips_thu = tips[tips['day'] == 'Thur']['tip']
tips_fri = tips[tips['day'] == 'Fri']['tip']
tips_sat = tips[tips['day'] == 'Sat']['tip']
tips_sun = tips[tips['day'] == 'Sun']['tip']

plt.boxplot(x=np.array([tips_thu, tips_fri, tips_sat, tips_sun], dtype='object'),
            labels=['Thu', 'Fri', 'Sat', 'Sun'])
plt.show()
# tips.day.unique()

# %%
days = tips.day.unique()

tip_by_day = []
for d in days:
    tip_by_day.append(tips[tips['day'] == d]['tip'])
    
plt.boxplot(x=tip_by_day, labels=days)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
tips_lunch = tips[tips['time'] == 'Lunch']['tip']
tips_dinner = tips[tips['time'] == 'Dinner']['tip']

plt.boxplot(x=np.array([tips_lunch, tips_dinner], dtype='object'),
            labels=['lunch', 'dinner'])
plt.show()

# %%
# subplot 4개를 2x2 형태로 배치 
# 성별 tip, 흡연여부별 tip, 요일별 tip, 시간별 tip boxplot
smoker_tip = tips[tips['smoker'] == 'Yes']['tip']
nonsmoker_tip = tips[tips['smoker'] == 'No']['tip']

# fig = plt.figure()
# ax1 = fig.add_subplot(221)

fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].boxplot(x=[male_tip, female_tip],
                   labels=['male', 'femlae'])
axes[0, 1].boxplot(x=[smoker_tip, nonsmoker_tip],
                   labels=['smoker', 'non-smoker'])
axes[1, 0].boxplot(x=tip_by_day, labels=days)
axes[1, 1].boxplot(x=[lunch_tip, dinner_tip],
                   labels=['lunch', 'dinner'])

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## 히스토그램(Histogram)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.hist(x=tips['total_bill'], bins=20)
plt.grid()
plt.show()

# %%
plt.hist(x=tips['total_bill'], density=True)
plt.grid()
plt.show()

# %%
plt.hist(x=tips['tip'], color='white', edgecolor='black')
plt.show()

# %% [markdown]
# ## 산점도 그래프(Scatter Plot)

# %%
# plot() 함수를 사용한 scatter plot - linestyle='', market='o'
# tip ~ total_bill 
# plt.plot(tips['total_bill'], tips['tip'], 'o')
plt.plot(tips['total_bill'], tips['tip'], marker='o', linestyle='')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.show()

# %%
# scatter() 함수를 사용한 scatter plot
plt.scatter(x=tips['total_bill'], y=tips['tip'],
            s=30,           # s: marker size
            c='orangered', # c: marker color
            marker='^',     # marker: marker 종류
            alpha=0.5)      # alpha: (불)투명도. 0(투명) ~ 1(불투명)
plt.show()

# %% [markdown]
# ## 막대 그래프(Bar plot)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 카테고리 타입의 변수의 빈도수를 찹음
gender_count = tips['sex'].value_counts()
print(gender_count, type(gender_count))
print(type(gender_count))
print(gender_count.index)
print(gender_count.values)
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64 <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category')
# [157  87]

# %%
# value_counts() 메서드가 리턴해주는 Series의 index와 values를 사용해서 막대 그래프를 그림
plt.bar(x=gender_count.index, height=gender_count.values, width=0.5)
plt.show()

# %%
plt.barh(y=gender_count.index, width=gender_count.values)
plt.show()

# %%
# figure에 2x2 모양으로 subplot을 추가 
# 각각의 subplot에 smoker, day, time, size의 막대 그래프를 그림
smoker_count = tips.smoker.value_counts()
print(smoker_count)
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
day_count = tips.day.value_counts()
print(day_count)
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
time_count = tips.time.value_counts()
print(time_count)
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
size_count = tips['size'].value_counts()
print(size_count)
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].bar(x=smoker_count.index, height=smoker_count.values)
axes[0, 0].set_title('Smoker')
axes[0, 1].bar(day_count.index, day_count.values)
axes[1, 0].bar(time_count.index, ime_count.values)
axes[1, 1].bar(size_count.index, size_count.values)

plt.show()

# %%
category_counts = [
                   tips['smoker'].value_counts(),
                   tips['day'].value_counts(),
                   tips['time'].value_counts(),
                   tips['size'].value_counts()
]

fig, axes = plt.subplots(nrows=2, ncols=2)
for row in range(2):
    for col in range(2):
        data = category_counts[row * 2 + col]
        axes[row, col].bar(data.index, data.values)

plt.show()
